# %% [markdown]
# # Entregável 1 - visão computacional

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print("OpenCV Version : %s " % cv2.__version__)
# Out:
# OpenCV Version : 3.4.3

# %% [markdown]
# # Equalização de histograma

# %%
rintin = cv2.imread("RinTinTin.jpg")

# %%
rintin.shape
# Out:
# (240, 320, 3)

# %%
rintin_gray = cv2.cvtColor(rintin, cv2.COLOR_RGB2GRAY)

# %%
rintin_gray.shape
# Out:
# (240, 320)

# %%
plt.imshow(rintin_gray, cmap="Greys_r", vmin=0, vmax=255)

# %%
hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Atividade 1
#
# Realize as seguintes atividades:
#
# 1. O histograma fornecido aproveita bem as faixas de cores?
# 2. Crie uma imagem derivada da imagem fornecida que use melhor a faixa dinâmica, ou seja, tenha o valor dos seus pixels distribuídos entre `0` e `255`.
# 3. Plote a imagem pedida

# %% [markdown]
# 1) N pq o vermelho se concentra nas fixas mais escuras
#
# 2)

# %%
img = rintin_gray

def func(pixel):
    return (255/50)*pixel - 40.8
    
    
saida = np.zeros((240, 320), dtype=np.uint8)

for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        saida[i][j] = func(img[i][j])

# %%
hist,bins = np.histogram(saida.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(saida.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# 3)

# %%
plt.imshow(saida, cmap="Greys_r", vmin=0, vmax=255);

# %% [markdown]
# ## Atividade 2

# %% [markdown]
# Leia com a OpenCV a figura abaixo:
#
# ![](hall_box_battery1.jpg)
#
# Separe os canais  R e B das imagens e analise seus histogramas.
#
# 1. A partir dos canais R e B e da análise do histograma é possível identificar a caixa vermelha e a bateria azul?
#
# 1. Crie uma imagem numpy em que somente os pixels da caixa vermelha estão brancos e faça seu plot aqui

# %% [markdown]
# 1)

# %%
batery = cv2.cvtColor(cv2.imread("hall_box_battery1.jpg"), cv2.COLOR_BGR2RGB)
plt.imshow(batery);

# %%
chn1 = batery[:,:,0]

hist,bins = np.histogram(chn1.flatten(),256,[0,256])

plt.hist(chn1.flatten(),256,[0,256], color = 'r')
plt.grid()
plt.show()

# %%
chn3 = batery[:,:,2]

hist,bins = np.histogram(chn3.flatten(),256,[0,256])

plt.hist(chn3.flatten(),256,[0,256], color = 'b')
plt.grid()
plt.show()

# %% [markdown]
# Não, pois as cores neutras são aquelas que possuem os valores de R, G e B parecidos, por conta disso é possível ver picos nos gráficos, já que na imagem muitas cores neutras são utilizadas. Fora isso, ao observar a imagem chanel 1, é possivel perceber que tanto o rodapé quanto a caixa vermlha tem a mesma cor, o que confirma que não é possível observa a caixa apeas pelos histogramas e a imagem dos canais.

# %% [markdown]
# 2)

# %%
saida_2 = batery.copy()
import numpy as np

for i in range(batery.shape[0]):
    for j in range(batery.shape[1]):
        
        if batery[i][j][0] >= 148 and batery[i][j][2] <= 110:
            saida_2[i][j] = np.asarray([255, 255, 255])
                
        else: 
            saida_2[i][j] = batery[i][j]

plt.imshow(saida_2);

# %% [markdown]
# # Atividade 3
#
#
# Abra a imagem `hall_box_battery_atividade3.png`  e a converta para tons de cinza de `0` a `255`.
#
# Forneça como saída uma uma cópia da imagem  em que cada pixel  recebe o módulo da subtração entre o pixel que vem depois e o que vem antes dele.
#
# Obs.: O conceito de *antes* e *depois* pode ser na horizontal ou na vertical
#
# Apresente a imagem resultado, deve ficar parecida com a imagem `gabarito_atividade_3.png`.
#
# <img src="gabarito_atividade_3.png" width=400>

# %%
grey_image = cv2.cvtColor(cv2.imread("hall_box_battery_atividade3.png"), cv2.COLOR_RGB2GRAY)
plt.imshow(grey_image, cmap="Greys_r", vmin=0, vmax=255);
